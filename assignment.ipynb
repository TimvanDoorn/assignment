# %%
import numpy as np
import pandas as pd
import os
import csv

# %%
# %%bash
#
# pip install plotly
# Out:
# ...
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import plotly.graph_objects as go

# %%
pwd
# Out:
# '/home/u1272706'

# %%
df = pd.read_csv('african_crises.csv')
df.sort_values(['inflation_crises', 'inflation_annual_cpi'], ascending=[1,0])
indexOutliers = df[ (df['inflation_crises'] == 0) & (df['inflation_annual_cpi'] > 20)].index
df.drop(indexOutliers, inplace = True)
indexOutliers1 = df[ (df['year'] < 1953)].index
df.drop(indexOutliers1, inplace = True)
df
# Out:
#       case  cc3   country  year  systemic_crisis      exch_usd  \
# 29       1  DZA   Algeria  1953                0  3.500000e+00
# 30       1  DZA   Algeria  1954                0  3.500000e+00
# 31       1  DZA   Algeria  1955                0  3.500000e+00
# 32       1  DZA   Algeria  1956                0  3.500000e+00
# 33       1  DZA   Algeria  1957                0  4.199000e+00
# 34       1  DZA   Algeria  1958                0  4.906000e+00
# 35       1  DZA   Algeria  1959                0  4.909000e+00
# 36       1  DZA   Algeria  1960                0  4.937060e+00
# 37       1  DZA   Algeria  1961                0  4.937060e+00
# 38       1  DZA   Algeria  1968                0  4.937060e+00
# 39       1  DZA   Algeria  1969                0  4.937060e+00
# 40       1  DZA   Algeria  1970                0  4.937060e+00
# 41       1  DZA   Algeria  1971                0  4.644000e+00
# 42       1  DZA   Algeria  1972                0  4.556000e+00
# ...

# %%
df.describe()
# Out:
#              case         year  systemic_crisis    exch_usd  \
# count  771.000000   771.000000       771.000000  771.000000
# mean    36.614786  1983.869001         0.101167   56.446724
# std     23.306724    17.918422         0.301746  125.749799
# min      1.000000  1953.000000         0.000000    0.000000
# 25%     15.000000  1969.000000         0.000000    0.357125
# 50%     38.000000  1984.000000         0.000000    4.631000
# 75%     56.000000  1999.500000         0.000000   22.131180
# max     70.000000  2014.000000         1.000000  744.306139
#
#        domestic_debt_in_default  sovereign_external_debt_default  \
# count                771.000000                       771.000000
# mean                   0.054475                         0.201038
# std                    0.227099                         0.401036
# min                    0.000000                         0.000000
# 25%                    0.000000                         0.000000
# ...

# %%
df1 = pd.read_csv('african_crises1.csv')
indexOutliers = df1[ (df1['year'] <1953)].index
df1.drop(indexOutliers, inplace = True)
df1
# Out:
#      year  systemic_crisis    exch_usd  domestic_debt_in_default  \
# 83   1953         0.000000   33.561307                  0.000000
# 84   1954         0.000000   30.768259                  0.000000
# 85   1955         0.000000   30.765584                  0.000000
# 86   1956         0.000000   30.768173                  0.000000
# 87   1957         0.000000   44.634664                  0.000000
# 88   1958         0.000000   20.579145                  0.000000
# 89   1959         0.000000   20.638368                  0.000000
# 90   1960         0.000000   20.627157                  0.000000
# 91   1961         0.000000   20.621597                  0.000000
# 92   1962         0.000000   21.928390                  0.000000
# 93   1963         0.000000   23.931438                  0.000000
# 94   1964         0.000000   23.923839                  0.000000
# 95   1965         0.000000   23.937362                  0.090909
# ...
